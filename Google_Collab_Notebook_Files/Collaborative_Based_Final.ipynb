# %%
# !pip install kagglehub --upgrade

# %%
import kagglehub

# Download the dataset
kagglehub.dataset_download("undefinenull/million-song-dataset-spotify-lastfm")
# Out:
# '/kaggle/input/million-song-dataset-spotify-lastfm'

# %%
import os
from pathlib import Path

# Define the path to the cached dataset
cache_path = Path("/root/.cache/kagglehub/datasets/undefinenull/million-song-dataset-spotify-lastfm/versions/1")

# List files in the cache directory
if cache_path.exists():
    print("Files in cache directory:", os.listdir(cache_path))
else:
    print("Cache directory does not exist.")
# Out:
# Cache directory does not exist.

# %%
# Check the root cache directory
root_cache_path = Path("/root/.cache/kagglehub/datasets/")
if root_cache_path.exists():
    print("Contents of root cache directory:", os.listdir(root_cache_path))
else:
    print("Root cache directory does not exist.")
# Out:
# Root cache directory does not exist.

# %%
from google.colab import files
uploaded = files.upload()  # Upload the ZIP file here
# Out:
#      <input type="file" id="files-5a6fc774-6f3a-4024-b4e5-e78ef523d419" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a6fc774-6f3a-4024-b4e5-e78ef523d419">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# List all files in current directory
print("Files in current directory:")
print(os.listdir())

# List only ZIP files
print("\nZIP files found:")
print([f for f in os.listdir() if f.endswith(".zip")])
# Out:
# Files in current directory:
# ['.config', 'Music Info.csv (2) (1).zip', 'million_song_dataset', 'Music Info.csv (2).zip', 'sample_data']
#
# ZIP files found:
# ['Music Info.csv (2) (1).zip', 'Music Info.csv (2).zip']

# %%
import zipfile
import os

# Define ZIP file and target directory
zip_filename = "Music Info.csv (2).zip"
extract_dir = "million_song_dataset"

# Extract ZIP contents
with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# Confirm extraction
print("Extracted files:")
for file in os.listdir(extract_dir):
    print("-", file)
# Out:
# Extracted files:
# - Music Info.csv

# %%
import pandas as pd
from pathlib import Path

# Build path to extracted CSV
csv_path = Path(extract_dir) / "Music Info.csv"

# Load relevant columns
songs_df = pd.read_csv(csv_path, usecols=["track_id", "name", "artist", "spotify_preview_url"])

# Display preview
songs_df.head()
# Out:
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...

# %%
# Install Dask with DataFrame support
# !pip install "dask[dataframe]"

# %%
import zipfile

for zip_file in ['Music Info.csv (2).zip', 'Music Info.csv (2) (1).zip']:
    print(f"\n📦 Contents of {zip_file}:")
    with zipfile.ZipFile(zip_file, 'r') as z:
        print(z.namelist())
# Out:
# 📦 Contents of Music Info.csv (2).zip:
# ['Music Info.csv']
#
# 📦 Contents of Music Info.csv (2) (1).zip:
# ['Music Info.csv']

# %%
import os

print("Files in 'million_song_dataset':")
print(os.listdir("million_song_dataset"))
# Out:
# Files in 'million_song_dataset':
# ['Music Info.csv']

# %%
import os

print(os.listdir("million_song_dataset"))
# Out:
# ['Music Info.csv']

# %%
import pandas as pd

users_data_path = "/content/User_Listening_History.csv"
users_df = pd.read_csv(users_data_path)

users_df.head()
# Out:
#              track_id                                   user_id  playcount
# 0  TRIRLYL128F42539D1  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 1  TRFUPBA128F934F7E1  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 2  TRLQPQJ128F42AA94F  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 3  TRTUCUY128F92E1D24  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 4  TRHDDQG12903CB53EE  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0

# %%
df.npartitions
# Out:
# 5

# %%
df.visualize(tasks=True)

# %%
df.visualize(tasks=True)

# %%
import pandas as pd

songs_df = pd.read_csv("million_song_dataset/Music Info.csv")

print(songs_df.columns.tolist())
# Out:
# ['track_id', 'name', 'artist', 'spotify_preview_url', 'spotify_id', 'tags', 'genre', 'year', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

# %%
import pandas as pd

# Define the path to the CSV file
songs_data_path = "million_song_dataset/Music Info.csv"

# Define the columns you want to load
columns_to_use = [
    "track_id", "name", "artist", "spotify_preview_url"
]

# Load the CSV file with only the specified columns
try:
    songs_df = pd.read_csv(songs_data_path, usecols=columns_to_use)
    print("Data loaded successfully. Here are the first few rows:")
    print(songs_df.head())
except FileNotFoundError:
    print(f"❌ File not found: {songs_data_path}")
except ValueError as e:
    print(f"❌ ValueError: {e}")
except Exception as e:
    print(f"❌ An error occurred: {e}")
# Out:
# Data loaded successfully. Here are the first few rows:
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...

# %%
print(df.columns)
# Out:
# Index(['457e0c', '1'], dtype='object')

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', '.ipynb_checkpoints', 'million_song_dataset', 'mydask.png', 'User_Listening_History.csv', 'Music Info.csv (2).zip', 'sample_data']

# %%
import dask.dataframe as dd

users_data_path = "/content/User_Listening_History.csv"

df = dd.read_csv(users_data_path, dtype={'playcount': 'float64'})

# Just use .head() to preview data as pandas DataFrame
print(df.head())
# Out:
#              track_id                                   user_id  playcount
# 0  TRIRLYL128F42539D1  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 1  TRFUPBA128F934F7E1  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 2  TRLQPQJ128F42AA94F  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 3  TRTUCUY128F92E1D24  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 4  TRHDDQG12903CB53EE  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0

# %%
# Calculate the number of unique tracks in the dataset
unique_tracks = df["track_id"].nunique().compute()

print(f"Number of unique tracks: {unique_tracks}")
# Out:
# Number of unique tracks: 26199

# %%
# Calculate the number of unique users in the dataset
unique_users = df["user_id"].nunique().compute()

print(f"Number of unique users: {unique_users}")
# Out:
# Number of unique users: 117916

# %%
# Retrieve the list of unique track IDs
unique_track_ids = df["track_id"].unique().compute().tolist()

# %%
num_unique_track_ids = df["track_id"].nunique().compute()
print(num_unique_track_ids)
# Out:
# 26199

# %%
# Filter songs to include only those with track_ids present in the listening history
filtered_songs = songs_df[songs_df["track_id"].isin(unique_track_ids)].copy()

# Reset index for a clean DataFrame
filtered_songs.reset_index(drop=True, inplace=True)

# %%
filtered_songs
# Out:
#                  track_id                       name                 artist  \
# 0      TRIOREW128F424EAF0             Mr. Brightside            The Killers
# 1      TRRIVDJ128F429B0E8                 Wonderwall                  Oasis
# 2      TRUEIND128F93038C4                Take Me Out        Franz Ferdinand
# 3      TRIODZU128E078F3E2           Under the Bridge  Red Hot Chili Peppers
# 4      TRYEZGE128F92D04C8             Feel Good Inc.               Gorillaz
# ...                   ...                        ...                    ...
# 26194  TRPJBMG128F92D164E            Stretch My Arms                   Fact
# 26195  TRTBIEH128F427C13C       Let It All Come Down   Boom Boom Satellites
# 26196  TRMEHFD128F92E4557  The Revenge of Surf Queen  9mm Parabellum Bullet
# 26197  TRPIGDW12903CDEB2D            Slip of the Lip                   Fact
# 26198  TRGLMEM128F9322F63          Koi no Dependence            アンティック-珈琲店-
#
#                                      spotify_preview_url
# ...

# %%
filtered_songs[filtered_songs["name"] == "Crazy in Love"]
# Out:
#                 track_id           name   artist  \
# 2903  TROINZB128F932F740  Crazy in Love  Beyoncé
#
#                                     spotify_preview_url
# 2903  https://p.scdn.co/mp3-preview/807828ea7070bda7...

# %%
import dask.dataframe as dd
import numpy as np

# Step 1: Read the CSV file with the correct file path and specified dtypes
file_path = '/content/User_Listening_History.csv'
df = dd.read_csv(file_path, dtype={'playcount': 'float64'})

# Print the first few rows of the DataFrame to verify its contents
print(df.head())

# Step 2: Ensure playcount is numeric
df['playcount'] = df['playcount'].astype(np.float64)

# Step 3: Convert user_id and track_id to categorical
df = df.categorize(columns=['user_id', 'track_id'])

# Print the DataFrame info to verify the data types and non-null counts
print(df.info())

# If you need to convert user_id and track_id to numeric indices, you can do so like this:
# df['user_id'] = df['user_id'].cat.codes
# df['track_id'] = df['track_id'].cat.codes

# Continue with your further operations
# Out:
#              track_id                                   user_id  playcount
# 0  TRIRLYL128F42539D1  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 1  TRFUPBA128F934F7E1  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 2  TRLQPQJ128F42AA94F  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 3  TRTUCUY128F92E1D24  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 4  TRHDDQG12903CB53EE  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# <class 'dask_expr.DataFrame'>
# Columns: 3 entries, track_id to playcount
# dtypes: category(1), category(1), float64(1)None

# %%
df.visualize(tasks=True)

# %%
import dask.dataframe as dd
import numpy as np

# Step 1: Read the CSV file with the correct file path and specified dtypes
file_path = '/content/User_Listening_History.csv'
df = dd.read_csv(file_path, dtype={'playcount': 'float64'})

# Print the first few rows of the DataFrame to verify its contents
print(df.head())

# Step 2: Ensure playcount is numeric
df['playcount'] = df['playcount'].astype(np.float64)

# Step 3: Convert user_id and track_id to categorical and then to numeric indices
df = df.categorize(columns=['user_id', 'track_id'])
df['user_idx'] = df['user_id'].cat.as_known().cat.codes
df['track_idx'] = df['track_id'].cat.as_known().cat.codes

# Print the DataFrame info to verify the data types and non-null counts
print(df.head())

# Step 4: Compute the interaction matrix
interaction_array = df.groupby(['track_idx', 'user_idx'])['playcount'].sum().reset_index()

# Visualize the interaction array
interaction_array.visualize(tasks=True)
# Out:
#              track_id                                   user_id  playcount
# 0  TRIRLYL128F42539D1  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 1  TRFUPBA128F934F7E1  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 2  TRLQPQJ128F42AA94F  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 3  TRTUCUY128F92E1D24  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 4  TRHDDQG12903CB53EE  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
#              track_id                                   user_id  playcount  \
# 0  TRIRLYL128F42539D1  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 1  TRFUPBA128F934F7E1  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 2  TRLQPQJ128F42AA94F  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 3  TRTUCUY128F92E1D24  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
# 4  TRHDDQG12903CB53EE  b80344d063b5ccb3212f76538f3d9e43d87dca9e        1.0
#
#    user_idx  track_idx
# 0     84789       9171
# ...

# %%
# Step 4: Compute the interaction matrix
# Dask doesn't support pivot tables directly, so we aggregate manually
interaction_array = df.groupby(['track_idx', 'user_idx'])['playcount'].sum().reset_index()

interaction_array.visualize(tasks=True)

# %%
interaction_array
# Out:
# Dask DataFrame Structure:
#               track_idx user_idx playcount
# npartitions=1
#                   int16    int32   float64
#                     ...      ...       ...
# Dask Name: reset_index, 15 expressions
# Expr=ResetIndex(frame=Sum(frame=(Assign(frame=Assign(frame=Categorize(frame=Assign(frame=ArrowStringConversion(frame=FromMapProjectable(7616a2c))), categories={'user_id': 211466     00005c6177188f12fb5e2e82cdbd93e8a3f35e64
# 1031607    00008c7cc5606ba35c2595b0b3bb1630d4685028
# 893537     00009d93dc719d1dbaf13507725a03b9fdeebebb
# 1029246    0001c909dceb32d0e71d632efa7e1f9f860dd2a1
# 1192514    0002c81a39642097ab5446b63760f6dc7eea5f28
#                              ...
# 407113     fffd9635b33f412de8ed02e44e6564e3644cf3c6
# 1183224    fffdf827472c4298ebb0150a89b3db8cd2f9f7ef
# 921949     fffe0da00ae2cd125e8006bda1f7286ec5840642
# 303400     fffe6d1d8500f1c1f31bd63abce35c0f975a86bf
# 454969     fffea3d509760c984e7d40789804c0e5e289cc86
# ...

# %%
interaction_array = interaction_array.compute()

# %%
interaction_array
# Out:
#          track_idx  user_idx  playcount
# 0                0      1924        3.0
# 1                0      9435        1.0
# 2                0     14525        1.0
# 3                0     16365        2.0
# 4                0     28268        1.0
# ...            ...       ...        ...
# 1199957      26198    107076        1.0
# 1199958      26198    107569        1.0
# 1199959      26198    107630        1.0
# 1199960      26198    111562        1.0
# 1199961      26198    116521        1.0
#
# [1199962 rows x 3 columns]

# %%
# Step 5: Create a sparse matrix
# Collect the data into a NumPy-friendly format

row_indices = interaction_array['track_idx']
col_indices = interaction_array['user_idx']
values = interaction_array['playcount']

# %%
row_indices.nunique()
# Out:
# 26199

# %%
# Build a sparse matrix
n_tracks = unique_tracks
n_users = unique_users

sparse_matrix = csr_matrix((values, (row_indices, col_indices)), shape=(n_tracks, n_users))

print("Sparse matrix shape:", sparse_matrix.shape)
print("Non-zero elements:", sparse_matrix.nnz)
# Out:
# Sparse matrix shape: (26199, 117916)
# Non-zero elements: 1199962

# %%
sparse_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1199962 stored elements and shape (26199, 117916)>

# %%
(sparse_matrix.nnz / (sparse_matrix.shape[0] * sparse_matrix.shape[1]))*100
# Out:
# 0.03884275628169053

# %%
sparse_matrix[0]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 19 stored elements and shape (1, 117916)>

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
np.where(df['track_id'].cat.categories == "TROINZB128F932F740")
# Out:
# (array([14616]),)

# %%
ind = 17018

# %%
input_array = sparse_matrix[ind]

input_array
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 625 stored elements and shape (1, 117916)>

# %%
similarity_scores = cosine_similarity(input_array, sparse_matrix)

# %%
np.sort(similarity_scores)[-6:][::-1]
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.36265828, 0.42646999,
#         1.        ]])

# %%
similarity_scores.shape
# Out:
# (1, 26199)

# %%
np.argsort(similarity_scores.ravel())[-6:][::-1]
# Out:
# array([17018, 10471, 13892,   770, 21314,  4392])

# %%
recommendations = df['track_id'].cat.categories[np.argsort(similarity_scores.ravel())[-6:][::-1]]

# %%
recommendations
# Out:
# Index(['TRQRMNO128F4235E4D', 'TRJVAMJ128F42557E7', 'TRNKLSY128F92E3707',
#        'TRAPMLU128F92DCE25', 'TRUWMRX128F422059A', 'TRDZBOU128F92E43E3'],
#       dtype='string', name='track_id')

# %%
filtered_songs[filtered_songs["name"] == "Crazy in Love"]
# Out:
#                 track_id           name   artist  \
# 2903  TROINZB128F932F740  Crazy in Love  Beyoncé
#
#                                     spotify_preview_url
# 2903  https://p.scdn.co/mp3-preview/807828ea7070bda7...

# %%
filtered_songs[filtered_songs["track_id"].isin(recommendations)]
# Out:
#                  track_id                   name   artist  \
# 1433   TRQRMNO128F4235E4D  Grow Up and Blow Away   Metric
# 1796   TRUWMRX128F422059A               The List   Metric
# 1882   TRDZBOU128F92E43E3            Live It Out   Metric
# 12817  TRJVAMJ128F42557E7                   OSCA     東京事変
# 16210  TRAPMLU128F92DCE25          Cat & The Eye  Van She
# 25114  TRNKLSY128F92E3707        She'z N Control  Chromeo
#
#                                      spotify_preview_url
# 1433   https://p.scdn.co/mp3-preview/7364237ab925cbfa...
# 1796   https://p.scdn.co/mp3-preview/1477f9bed4e91a4d...
# 1882   https://p.scdn.co/mp3-preview/da748f07f8dfe198...
# 12817  https://p.scdn.co/mp3-preview/9206f6de40419c62...
# 16210  https://p.scdn.co/mp3-preview/b27951e3422ec1f9...
# 25114  https://p.scdn.co/mp3-preview/73f26e3a752ba809...

# %%
def collaborative_recommendation(song_name,user_data,songs_data,interaction_matrix,k=5):
    # fetch the row from songs data
    song_row = songs_data[songs_data["name"] == song_name]
    print(song_row)
    # track_id of input song
    input_track_id = song_row['track_id'].values.item()
    print(input_track_id)
    # index value of track_id
    ind = np.where(user_data['track_id'].cat.categories == input_track_id)[0].item()
    print(ind)
    # fetch the input vector
    input_array = interaction_matrix[ind]
    # get similarity scores
    similarity_scores = cosine_similarity(input_array, interaction_matrix)
    # get top k recommendations
    recommendation_track_ids = df['track_id'].cat.categories[np.argsort(similarity_scores.ravel())[-k-1:][::-1]]
    print(recommendation_track_ids)
    # get top scores
    top_scores = np.sort(similarity_scores.ravel())[-k-1:][::-1]
    print(top_scores)
    # get the songs from data and print
    temp_df = pd.DataFrame({"track_id":recommendation_track_ids.tolist(),
                            "score":top_scores})
    print(temp_df)
    top_k_songs = (
                    songs_data
                    .loc[songs_data["track_id"].isin(recommendation_track_ids)]
                    .merge(temp_df,on="track_id")
                    .sort_values(by="score",ascending=False)
                    .drop(columns=["track_id","score"])
                    .reset_index(drop=True)
                    )
    return top_k_songs

# %%
collaborative_recommendation(song_name="Crazy in Love",
                             user_data=df,
                             songs_data=filtered_songs,
                             interaction_matrix=sparse_matrix)
# Out:
#                 track_id           name   artist  \
# 2903  TROINZB128F932F740  Crazy in Love  Beyoncé
#
#                                     spotify_preview_url
# 2903  https://p.scdn.co/mp3-preview/807828ea7070bda7...
# TROINZB128F932F740
# 14616
# Index(['TROINZB128F932F740', 'TRUQOZD128F930F4D1', 'TRUUILJ128F425750F',
#        'TRVOSVY128F92FFA74', 'TRGGULV128F4295F6A', 'TROREII12903CC71E3'],
#       dtype='string', name='track_id')
# [1.         0.27907692 0.15144242 0.12808889 0.0896248  0.0895682 ]
#              track_id     score
# 0  TROINZB128F932F740  1.000000
# 1  TRUQOZD128F930F4D1  0.279077
# 2  TRUUILJ128F425750F  0.151442
# 3  TRVOSVY128F92FFA74  0.128089
# 4  TRGGULV128F4295F6A  0.089625
# 5  TROREII12903CC71E3  0.089568
#                            name                 artist  \
# 0                 Crazy in Love                Beyoncé
# 1                    South Side                   Moby
# 2                    The Ascent  The Devil Wears Prada
# ...
